# %%
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import requests, re, os, path

# %%
def obterDadosBasicos(job_html):
    # job title
    title_html = job_html.find('h2').find('a', class_='s-link')
    job = {'title': title_html.text if title_html else None}

    # job company and location
    company, location = tuple(job_html.find('div', class_='-company').select('span'))
    job['company'], job['location'] = company.text, location.text

    # job posted
    job['posted'] = job_html.find('div', class_='-title').find('span', class_='pt2').text

    # request date
    job['request_date'] = datetime.now()

    # job salary and perks
    perks_html = job_html.find('div', class_='-perks')
    if perks_html:
        perks = []
        for p in perks_html.select('span'):

            if '-salary' in str(p):
                job['salary'] = p.text.strip()
            else:
                perks.append(p.text.strip())

        job['perks'] = ', '.join(perks)


    # job tags
    tags_html = job_html.find('div', class_='-tags')
    if tags_html:
        tags = [a.text for a in tags_html.select('a')]
        job['tags'] = ', '.join(tags)  
        
    return job


def get_detail(details, description):
    try:
        return details.find('span', text=description).find_next().getText()                    
    except: 
        return None
            
            
def obterDetalhes(job_html, job):
    link = job_html.find('h2', class_='fs-subheading').select_one('a')
    job['link']  = link['href']
    
    url = 'https://stackoverflow.com/{path}'.format(path= job['link'])
    text = fazer_requisicao(url)
    soup = BeautifulSoup(text, 'lxml')

    
    details = soup.find('div', class_='job-details--about')
    job['job-type'] = get_detail(details, 'Job type: ')
    job['experience-level'] = get_detail(details, 'Experience level: ')
    job['role'] = get_detail(details, 'Role: ')
    job['industry'] = get_detail(details, 'Industry: ')
    job['company-size'] = get_detail(details, 'Company size: ')
    job['company-type'] = get_detail(details, 'Company type: ')
    

    description = soup.find('h2', text='Job description')
    job['description'] = description.find_next('div').get_text() if description else None

    return job


def fazer_requisicao(url):
    filename_cache = 'cache/%s'%url.replace('/', '')
    
    if os.path.exists(filename_cache):
        with open(filename_cache, 'r') as f:
            return f.read()
    else:
        res = requests.get(url)
        res.raise_for_status()
        
        with open(filename_cache, 'w') as f:
            f.write(res.text)
            
    return res.text
    


def collect_jobs_stackoverflow():
    jobs = []    
    
    for pag in range(1, 43):
        try:
            url = 'https://stackoverflow.com/jobs?med=site-ui&ref=jobs-tab&sort=i&pg=%d'%pag
            text = fazer_requisicao(url)
            soup = BeautifulSoup(text, 'lxml')

            # Jobs list html
            jobs_html = soup.find('div', class_='listResults').findAll('div', class_='-job')

            for job_html in jobs_html:
                job = obterDadosBasicos(job_html)            
                job = obterDetalhes(job_html, job)

                jobs.append(job)

        except Exception as e:
            print(e, 'Página: ', pag)
            break
            
            
    return jobs

# %%
jobs = collect_jobs_stackoverflow()

# %%
#jobs

# %%
df = pd.DataFrame(jobs)

# %%
df.shape
# Out:
# (1050, 16)

# %%
df.head(10)
# Out:
#                                     company   company-size company-type  \
# 0                  Etiometry Inc.\n           11-50 people      Private
# 1                   The Real Real\n           1k-5k people      Private
# 2               Pear Therapeutics\n          51-200 people      Private
# 3  Integrated Data Services (IDS)\n          51-200 people      Private
# 4  Integrated Data Services (IDS)\n          51-200 people      Private
# 5  Integrated Data Services (IDS)\n          51-200 people      Private
# 6                         Alegion\n           11-50 people    VC Funded
# 7                            Hays\n          5k-10k people       Public
# 8              The Quantium Group\n          501-1k people      Private
# 9                        Hays plc\n          5k-10k people       Public
#
#                                          description         experience-level  \
# 0  \nWe are currently seeking a Data Scientist to...                Mid-Level
# 1  \nThe RealReal is leading the way in authentic...  Mid-Level, Senior, Lead
# 2  \nAbout Pear Therapeutics \nAt Pear, our missi...        Mid-Level, Senior
# 3  \nSenior Java Developer\nLos Angeles, CA; Wash...                   Senior
# 4  \nSenior Oracle PLSQL Developer\nLos Angeles, ...                   Senior
# 5  \nSenior UI Developer\nLos Angeles, CA; Washin...                   Senior
# 6  \nTHE OPPORTUNITY\nThe Applied Machine Learnin...        Mid-Level, Senior
# 7  \nHays Specialist Recruitment is working in pa...                Mid-Level
# 8  \nFor over 15 years Quantium have combined the...                     Lead
# 9  \nHays have teamed up with NAB (National Austr...             Senior, Lead
#
#                                             industry   job-type  \
# 0     Data & Analytics, Healthcare, Medical Software  Full-time
# 1                         eCommerce, Fashion, Retail  Full-time
# 2                                      Biotechnology  Full-time
# 3  Financial Technology, Government, Software Dev...  Full-time
# 4  Financial Technology, Government, Software Dev...  Full-time
# 5  Financial Technology, Government, Software Dev...  Full-time
# 6  Artificial Intelligence, Computer Vision, Mach...  Full-time
# 7    digital recruitment, IT Recruitment, Recruiting  Full-time
# 8           Big Data, Data & Analytics, Data Science  Full-time
# 9    digital recruitment, IT Recruitment, Recruiting  Full-time
#
#                                                 link  \
# 0          /jobs/199604/data-scientist-etiometry-inc
# 1  /jobs/199609/senior-platform-developer-backend...
# 2  /jobs/204842/senior-platform-engineer-pear-the...
# 3  /jobs/157266/senior-java-developer-integrated-...
# 4  /jobs/141988/senior-oracle-plsql-developer-int...
# 5  /jobs/157265/senior-u-i-developer-integrated-d...
# 6  /jobs/217831/applied-machine-learning-engineer...
# 7  /jobs/173557/consulting-level-data-scientist-hays
# 8  /jobs/204837/tech-focused-data-scientist-r-d-p...
# 9  /jobs/201842/react-native-engineer-senior-lead...
#
#                                        location            perks    posted  \
# 0         \n             - \nBoston, MA          Paid relocation    3h ago
# 1  \n             - \nSan Francisco, CA                      NaN  < 1h ago
# 2  \n             - \nSan Francisco, CA                      NaN  < 1h ago
# 3    \n             - \nLos Angeles, CA                   Remote  < 1h ago
# 4    \n             - \nLos Angeles, CA                   Remote  < 1h ago
# 5    \n             - \nLos Angeles, CA                   Remote  < 1h ago
# 6         \n             - \nAustin, TX          Paid relocation  < 1h ago
# 7        \n             - \nRaleigh, NC                      NaN    1h ago
# 8  \n             - \nSydney, Australia             Visa sponsor    2h ago
# 9  \n             - \nSydney, Australia                             2h ago
#
#                 request_date                          role        salary  \
# 0 2019-01-07 22:51:19.033107                Data Scientist           NaN
# 1 2019-01-07 22:51:19.064124             Backend Developer           NaN
# 2 2019-01-07 22:51:19.095266          Full Stack Developer           NaN
# 3 2019-01-07 22:51:19.125580          Full Stack Developer           NaN
# 4 2019-01-07 22:51:19.160225        Database Administrator           NaN
# 5 2019-01-07 22:51:19.193965  Frontend Developer, Designer           NaN
# 6 2019-01-07 22:51:19.229565          Full Stack Developer        Equity
# 7 2019-01-07 22:51:19.258602                Data Scientist           NaN
# 8 2019-01-07 22:51:19.290449                Data Scientist           NaN
# 9 2019-01-07 22:51:19.322576              Mobile Developer  A$10k - 160k
#
#                                                 tags  \
# 0                      python, medical, data-science
# 1                              ruby-on-rails, elixir
# 2     node.js, mysql, rest, ecmascript-6, javascript
# 3           java-ee, spring, oracle, weblogic, jboss
# 4      plsql, oracle, sql, rdbms, database, sysadmin
# 5    javascript, angularjs, html, ui-design, angular
# 6  machine-learning, computer-vision, python, jav...
# 7                         r, python, spark, sql, git
# 8                 scala, hadoop, go, r, apache-spark
# 9    react-native, reactjs, mobile, javascript, java
#
#                                                title
# 0                                     Data Scientist
# 1      Senior Platform Developer (Backend Developer)
# 2                           Senior Platform Engineer
# 3                              Senior Java Developer
# 4                      Senior Oracle PLSQL Developer
# 5                               Senior U/I Developer
# 6                  Applied Machine Learning Engineer
# 7                   Consulting Level Data Scientist
# 8  Tech focused Data Scientist – R&D Platforms An...
# 9               React Native Engineer, Senior / Lead

# %%
df.to_csv('data/Stack_Overflow_Jobs.csv', index=False)
