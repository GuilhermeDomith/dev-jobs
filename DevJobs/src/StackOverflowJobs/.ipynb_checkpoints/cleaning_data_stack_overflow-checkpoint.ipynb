# %%
import pandas as pd
import datetime as dt
import re, math
import numpy as np
import json

# %%
df = pd.read_csv('data/Stack_Overflow_Jobs.csv')
df.shape
# Out:
# (1050, 16)

# %%
df.head()
# Out:
#                                     company   company-size company-type  \
# 0                  Etiometry Inc.\n           11-50 people      Private
# 1                   The Real Real\n           1k-5k people      Private
# 2               Pear Therapeutics\n          51-200 people      Private
# 3  Integrated Data Services (IDS)\n          51-200 people      Private
# 4  Integrated Data Services (IDS)\n          51-200 people      Private
#
#                                          description         experience-level  \
# 0  \nWe are currently seeking a Data Scientist to...                Mid-Level
# 1  \nThe RealReal is leading the way in authentic...  Mid-Level, Senior, Lead
# 2  \nAbout Pear Therapeutics \nAt Pear, our missi...        Mid-Level, Senior
# 3  \nSenior Java Developer\nLos Angeles, CA; Wash...                   Senior
# 4  \nSenior Oracle PLSQL Developer\nLos Angeles, ...                   Senior
#
#                                             industry   job-type  \
# 0     Data & Analytics, Healthcare, Medical Software  Full-time
# 1                         eCommerce, Fashion, Retail  Full-time
# 2                                      Biotechnology  Full-time
# 3  Financial Technology, Government, Software Dev...  Full-time
# 4  Financial Technology, Government, Software Dev...  Full-time
#
#                                                 link  \
# 0          /jobs/199604/data-scientist-etiometry-inc
# 1  /jobs/199609/senior-platform-developer-backend...
# 2  /jobs/204842/senior-platform-engineer-pear-the...
# 3  /jobs/157266/senior-java-developer-integrated-...
# 4  /jobs/141988/senior-oracle-plsql-developer-int...
#
#                                        location            perks    posted  \
# 0         \n             - \nBoston, MA          Paid relocation    3h ago
# 1  \n             - \nSan Francisco, CA                      NaN  < 1h ago
# 2  \n             - \nSan Francisco, CA                      NaN  < 1h ago
# 3    \n             - \nLos Angeles, CA                   Remote  < 1h ago
# 4    \n             - \nLos Angeles, CA                   Remote  < 1h ago
#
#                  request_date                    role salary  \
# 0  2019-01-07 22:51:19.033107          Data Scientist    NaN
# 1  2019-01-07 22:51:19.064124       Backend Developer    NaN
# 2  2019-01-07 22:51:19.095266    Full Stack Developer    NaN
# 3  2019-01-07 22:51:19.125580    Full Stack Developer    NaN
# 4  2019-01-07 22:51:19.160225  Database Administrator    NaN
#
#                                              tags  \
# 0                   python, medical, data-science
# 1                           ruby-on-rails, elixir
# 2  node.js, mysql, rest, ecmascript-6, javascript
# 3        java-ee, spring, oracle, weblogic, jboss
# 4   plsql, oracle, sql, rdbms, database, sysadmin
#
#                                            title
# 0                                 Data Scientist
# 1  Senior Platform Developer (Backend Developer)
# 2                       Senior Platform Engineer
# 3                          Senior Java Developer
# 4                  Senior Oracle PLSQL Developer

# %% [markdown]
# ### Processando a coluna Location

# %%
def clear_location(x):
    if 'No office location' in x:
        return None
    
    loc = x.split()
    if '-' in loc:
        loc.remove('-')
    return ' '.join(loc)

df['location'] = df['location'].apply(clear_location)
df.head()
# Out:
#                                     company   company-size company-type  \
# 0                  Etiometry Inc.\n           11-50 people      Private
# 1                   The Real Real\n           1k-5k people      Private
# 2               Pear Therapeutics\n          51-200 people      Private
# 3  Integrated Data Services (IDS)\n          51-200 people      Private
# 4  Integrated Data Services (IDS)\n          51-200 people      Private
#
#                                          description         experience-level  \
# 0  \nWe are currently seeking a Data Scientist to...                Mid-Level
# 1  \nThe RealReal is leading the way in authentic...  Mid-Level, Senior, Lead
# 2  \nAbout Pear Therapeutics \nAt Pear, our missi...        Mid-Level, Senior
# 3  \nSenior Java Developer\nLos Angeles, CA; Wash...                   Senior
# 4  \nSenior Oracle PLSQL Developer\nLos Angeles, ...                   Senior
#
#                                             industry   job-type  \
# 0     Data & Analytics, Healthcare, Medical Software  Full-time
# 1                         eCommerce, Fashion, Retail  Full-time
# 2                                      Biotechnology  Full-time
# 3  Financial Technology, Government, Software Dev...  Full-time
# 4  Financial Technology, Government, Software Dev...  Full-time
#
#                                                 link           location  \
# 0          /jobs/199604/data-scientist-etiometry-inc         Boston, MA
# 1  /jobs/199609/senior-platform-developer-backend...  San Francisco, CA
# 2  /jobs/204842/senior-platform-engineer-pear-the...  San Francisco, CA
# 3  /jobs/157266/senior-java-developer-integrated-...    Los Angeles, CA
# 4  /jobs/141988/senior-oracle-plsql-developer-int...    Los Angeles, CA
#
#              perks    posted                request_date  \
# 0  Paid relocation    3h ago  2019-01-07 22:51:19.033107
# 1              NaN  < 1h ago  2019-01-07 22:51:19.064124
# 2              NaN  < 1h ago  2019-01-07 22:51:19.095266
# 3           Remote  < 1h ago  2019-01-07 22:51:19.125580
# 4           Remote  < 1h ago  2019-01-07 22:51:19.160225
#
#                      role salary  \
# 0          Data Scientist    NaN
# 1       Backend Developer    NaN
# 2    Full Stack Developer    NaN
# 3    Full Stack Developer    NaN
# 4  Database Administrator    NaN
#
#                                              tags  \
# 0                   python, medical, data-science
# 1                           ruby-on-rails, elixir
# 2  node.js, mysql, rest, ecmascript-6, javascript
# 3        java-ee, spring, oracle, weblogic, jboss
# 4   plsql, oracle, sql, rdbms, database, sysadmin
#
#                                            title
# 0                                 Data Scientist
# 1  Senior Platform Developer (Backend Developer)
# 2                       Senior Platform Engineer
# 3                          Senior Java Developer
# 4                  Senior Oracle PLSQL Developer

# %% [markdown]
# ### Criando a coluna Country

# %%
def separate_country(row):
    if not row.location:
        row['location'], row['country'] = (None, None)
    else:
        row['location'], _, row['country'] = row.location.partition(', ')
        
    return row
    
df = df.apply(separate_country, axis=1)
df.head()
# Out:
#                                     company   company-size company-type  \
# 0                  Etiometry Inc.\n           11-50 people      Private
# 1                   The Real Real\n           1k-5k people      Private
# 2               Pear Therapeutics\n          51-200 people      Private
# 3  Integrated Data Services (IDS)\n          51-200 people      Private
# 4  Integrated Data Services (IDS)\n          51-200 people      Private
#
#                                          description         experience-level  \
# 0  \nWe are currently seeking a Data Scientist to...                Mid-Level
# 1  \nThe RealReal is leading the way in authentic...  Mid-Level, Senior, Lead
# 2  \nAbout Pear Therapeutics \nAt Pear, our missi...        Mid-Level, Senior
# 3  \nSenior Java Developer\nLos Angeles, CA; Wash...                   Senior
# 4  \nSenior Oracle PLSQL Developer\nLos Angeles, ...                   Senior
#
#                                             industry   job-type  \
# 0     Data & Analytics, Healthcare, Medical Software  Full-time
# 1                         eCommerce, Fashion, Retail  Full-time
# 2                                      Biotechnology  Full-time
# 3  Financial Technology, Government, Software Dev...  Full-time
# 4  Financial Technology, Government, Software Dev...  Full-time
#
#                                                 link       location  \
# 0          /jobs/199604/data-scientist-etiometry-inc         Boston
# 1  /jobs/199609/senior-platform-developer-backend...  San Francisco
# 2  /jobs/204842/senior-platform-engineer-pear-the...  San Francisco
# 3  /jobs/157266/senior-java-developer-integrated-...    Los Angeles
# 4  /jobs/141988/senior-oracle-plsql-developer-int...    Los Angeles
#
#              perks    posted                request_date  \
# 0  Paid relocation    3h ago  2019-01-07 22:51:19.033107
# 1              NaN  < 1h ago  2019-01-07 22:51:19.064124
# 2              NaN  < 1h ago  2019-01-07 22:51:19.095266
# 3           Remote  < 1h ago  2019-01-07 22:51:19.125580
# 4           Remote  < 1h ago  2019-01-07 22:51:19.160225
#
#                      role salary  \
# 0          Data Scientist    NaN
# 1       Backend Developer    NaN
# 2    Full Stack Developer    NaN
# 3    Full Stack Developer    NaN
# 4  Database Administrator    NaN
#
#                                              tags  \
# 0                   python, medical, data-science
# 1                           ruby-on-rails, elixir
# 2  node.js, mysql, rest, ecmascript-6, javascript
# 3        java-ee, spring, oracle, weblogic, jboss
# 4   plsql, oracle, sql, rdbms, database, sysadmin
#
#                                            title country
# 0                                 Data Scientist      MA
# 1  Senior Platform Developer (Backend Developer)      CA
# 2                       Senior Platform Engineer      CA
# 3                          Senior Java Developer      CA
# 4                  Senior Oracle PLSQL Developer      CA

# %% [markdown]
# ### Processando a coluna Posted

# %%
df.posted.unique()
# Out:
# array(['3h ago', '< 1h ago', '1h ago', '2h ago', '4h ago', '5h ago',
#        '6h ago', '7h ago', '8h ago', '9h ago', '10h ago', '11h ago',
#        '12h ago', '13h ago', '14h ago', '15h ago', '17h ago', '16h ago',
#        '20h ago', '18h ago', '19h ago', '22h ago', 'yesterday', '2d ago',
#        '3d ago'], dtype=object)

# %%
def replace_times_ago_to_date(row):
    times_ago, req_date = row['posted'], row['request_date']
    
    req_date = dt.datetime.strptime(req_date, "%Y-%m-%d %H:%M:%S.%f")
    numero = re.sub('[^\d]', '',times_ago)

    if 'h ago' in times_ago:
        return req_date - dt.timedelta(hours= int(numero))
    elif 'd ago' in times_ago:
        return req_date - dt.timedelta(days= int(numero))
    else:
        return req_date - dt.timedelta(days= 1)
                 
df['posted'] = df.apply(replace_times_ago_to_date, axis=1)
df.head()
# Out:
#                                     company   company-size company-type  \
# 0                  Etiometry Inc.\n           11-50 people      Private
# 1                   The Real Real\n           1k-5k people      Private
# 2               Pear Therapeutics\n          51-200 people      Private
# 3  Integrated Data Services (IDS)\n          51-200 people      Private
# 4  Integrated Data Services (IDS)\n          51-200 people      Private
#
#                                          description         experience-level  \
# 0  \nWe are currently seeking a Data Scientist to...                Mid-Level
# 1  \nThe RealReal is leading the way in authentic...  Mid-Level, Senior, Lead
# 2  \nAbout Pear Therapeutics \nAt Pear, our missi...        Mid-Level, Senior
# 3  \nSenior Java Developer\nLos Angeles, CA; Wash...                   Senior
# 4  \nSenior Oracle PLSQL Developer\nLos Angeles, ...                   Senior
#
#                                             industry   job-type  \
# 0     Data & Analytics, Healthcare, Medical Software  Full-time
# 1                         eCommerce, Fashion, Retail  Full-time
# 2                                      Biotechnology  Full-time
# 3  Financial Technology, Government, Software Dev...  Full-time
# 4  Financial Technology, Government, Software Dev...  Full-time
#
#                                                 link       location  \
# 0          /jobs/199604/data-scientist-etiometry-inc         Boston
# 1  /jobs/199609/senior-platform-developer-backend...  San Francisco
# 2  /jobs/204842/senior-platform-engineer-pear-the...  San Francisco
# 3  /jobs/157266/senior-java-developer-integrated-...    Los Angeles
# 4  /jobs/141988/senior-oracle-plsql-developer-int...    Los Angeles
#
#              perks                     posted                request_date  \
# 0  Paid relocation 2019-01-07 19:51:19.033107  2019-01-07 22:51:19.033107
# 1              NaN 2019-01-07 21:51:19.064124  2019-01-07 22:51:19.064124
# 2              NaN 2019-01-07 21:51:19.095266  2019-01-07 22:51:19.095266
# 3           Remote 2019-01-07 21:51:19.125580  2019-01-07 22:51:19.125580
# 4           Remote 2019-01-07 21:51:19.160225  2019-01-07 22:51:19.160225
#
#                      role salary  \
# 0          Data Scientist    NaN
# 1       Backend Developer    NaN
# 2    Full Stack Developer    NaN
# 3    Full Stack Developer    NaN
# 4  Database Administrator    NaN
#
#                                              tags  \
# 0                   python, medical, data-science
# 1                           ruby-on-rails, elixir
# 2  node.js, mysql, rest, ecmascript-6, javascript
# 3        java-ee, spring, oracle, weblogic, jboss
# 4   plsql, oracle, sql, rdbms, database, sysadmin
#
#                                            title country
# 0                                 Data Scientist      MA
# 1  Senior Platform Developer (Backend Developer)      CA
# 2                       Senior Platform Engineer      CA
# 3                          Senior Java Developer      CA
# 4                  Senior Oracle PLSQL Developer      CA

# %%
df = df.drop(['request_date'], axis=1)

# %% [markdown]
# ### Processando a coluna Salary

# %%
# Valor para conversão de uma moeda para Real
moedas = {
    'R$': 1, # Real
    'C$': 2.88, # Dolar Canadense
    '£': 4.91, # Libra esterlina, Reino Unido
    '€': 4.30, # Euro
    '₹': 0.052, # Rúpia indiana
    'A$': 2.75, # Dolar Australiano
    'zł': 1, # Zloti polonês
    'SEK': 0.42, # Coroa Sueca
    'CHF': 3.76, # Franco suíço
    'MXN': 0.19, # Peso mexicano
    'R': 0.26, # Rand Sul-Africano
    '$': 3.78, # Dolar Americano
}

# %%
def clear_salary(row):
    row['moeda_original'] = '-'
    
    if isinstance(row['salary'], float):
        return row
    
    for moeda in moedas.keys():
        if moeda in row['salary']:
            min_max_list = re.sub('[^\d-]','', row['salary']).split('-')

            if len(min_max_list) == 2:
                row['salary_min'], row['salary_max'] = tuple(min_max_list)
            else:
                row['salary_max'] = min_max_list[0]

            row['moeda_original'] = moeda
            break
    
    return row

df = df.apply(clear_salary, axis=1)
df.head()
# Out:
#                                     company   company-size company-type  \
# 0                  Etiometry Inc.\n           11-50 people      Private
# 1                   The Real Real\n           1k-5k people      Private
# 2               Pear Therapeutics\n          51-200 people      Private
# 3  Integrated Data Services (IDS)\n          51-200 people      Private
# 4  Integrated Data Services (IDS)\n          51-200 people      Private
#
#   country                                        description  \
# 0      MA  \nWe are currently seeking a Data Scientist to...
# 1      CA  \nThe RealReal is leading the way in authentic...
# 2      CA  \nAbout Pear Therapeutics \nAt Pear, our missi...
# 3      CA  \nSenior Java Developer\nLos Angeles, CA; Wash...
# 4      CA  \nSenior Oracle PLSQL Developer\nLos Angeles, ...
#
#           experience-level                                           industry  \
# 0                Mid-Level     Data & Analytics, Healthcare, Medical Software
# 1  Mid-Level, Senior, Lead                         eCommerce, Fashion, Retail
# 2        Mid-Level, Senior                                      Biotechnology
# 3                   Senior  Financial Technology, Government, Software Dev...
# 4                   Senior  Financial Technology, Government, Software Dev...
#
#     job-type                                               link  \
# 0  Full-time          /jobs/199604/data-scientist-etiometry-inc
# 1  Full-time  /jobs/199609/senior-platform-developer-backend...
# 2  Full-time  /jobs/204842/senior-platform-engineer-pear-the...
# 3  Full-time  /jobs/157266/senior-java-developer-integrated-...
# 4  Full-time  /jobs/141988/senior-oracle-plsql-developer-int...
#
#         location moeda_original            perks                     posted  \
# 0         Boston              -  Paid relocation 2019-01-07 19:51:19.033107
# 1  San Francisco              -              NaN 2019-01-07 21:51:19.064124
# 2  San Francisco              -              NaN 2019-01-07 21:51:19.095266
# 3    Los Angeles              -           Remote 2019-01-07 21:51:19.125580
# 4    Los Angeles              -           Remote 2019-01-07 21:51:19.160225
#
#                      role salary salary_max salary_min  \
# 0          Data Scientist    NaN        NaN        NaN
# 1       Backend Developer    NaN        NaN        NaN
# 2    Full Stack Developer    NaN        NaN        NaN
# 3    Full Stack Developer    NaN        NaN        NaN
# 4  Database Administrator    NaN        NaN        NaN
#
#                                              tags  \
# 0                   python, medical, data-science
# 1                           ruby-on-rails, elixir
# 2  node.js, mysql, rest, ecmascript-6, javascript
# 3        java-ee, spring, oracle, weblogic, jboss
# 4   plsql, oracle, sql, rdbms, database, sysadmin
#
#                                            title
# 0                                 Data Scientist
# 1  Senior Platform Developer (Backend Developer)
# 2                       Senior Platform Engineer
# 3                          Senior Java Developer
# 4                  Senior Oracle PLSQL Developer

# %% [markdown]
# ### Replace Countries

# %%
df['country'] = df['country'].replace({
    'Deutschland': 'Alemanha',
    'Germany': 'Alemanha',
    'UK': 'Reino Unido',
    'Netherlands': 'Holanda',
    'Sweden': 'Suécia',
    'France': 'França',
    'Schweiz': 'Suíça',
    'Norway': 'Noruega',
    'Switzerland': 'Suíça',
    'Poland': 'Polônia',
    'Romania': 'Romênia',
    'Belgium': 'Bélgica',
    'Österreich': 'Áustria'
})

# %% [markdown]
# ### Replace Contry EUA

# %%
df['country'] = df['country'].replace({
    'TX': 'Texas, EUA',
    'CA': 'Califórnia, EUA',
    'VA': 'Virgínia, EUA',
    'NY': 'Nova York, EUA',
    'CO': 'Colorado, EUA',
    'PA': 'Pensilvânia, EUA',
    'MA': 'Massachusetts, EUA',
    'IL': 'Illinois, EUA',
    'NJ': 'Nova Jersey, EUA',
    'UT': 'Utah, EUA',
    'OH': 'Ohio, EUA',
    'FL': 'Flórida, EUA',
    'WI': 'Wisconsin, EUA',
    'DC': 'Washington, EUA',
    'TN': 'Tennessee, EUA',
    'MI': 'Michigan, EUA',
    'WA': 'Washington, EUA',
    'MD': 'Maryland, EUA',
    'IN': 'Indiana, EUA',
    'AZ': 'Arizona, EUA',
    'DE': 'Delaware, EUA',
    'GA': 'Georgia, EUA',
    'MO': 'Missouri, EUA',
    'NC': 'Carolina do Norte, EUA'
})

# %% [markdown]
# ### Convertendo a moeda para Real
#    - Converte cada valor para a moeda Real de acordo com a cotação definida em _moedas_
#    - Coverte o salário anual para mensal
#    - Calcula a média entre o mínimo e máximo

# %%
df[['salary_min', 'salary_max', 'salary']] = df[['salary_min', 'salary_max', 'salary']].fillna(0)
df.head()
# Out:
#                                     company   company-size company-type  \
# 0                  Etiometry Inc.\n           11-50 people      Private
# 1                   The Real Real\n           1k-5k people      Private
# 2               Pear Therapeutics\n          51-200 people      Private
# 3  Integrated Data Services (IDS)\n          51-200 people      Private
# 4  Integrated Data Services (IDS)\n          51-200 people      Private
#
#               country                                        description  \
# 0  Massachusetts, EUA  \nWe are currently seeking a Data Scientist to...
# 1     Califórnia, EUA  \nThe RealReal is leading the way in authentic...
# 2     Califórnia, EUA  \nAbout Pear Therapeutics \nAt Pear, our missi...
# 3     Califórnia, EUA  \nSenior Java Developer\nLos Angeles, CA; Wash...
# 4     Califórnia, EUA  \nSenior Oracle PLSQL Developer\nLos Angeles, ...
#
#           experience-level                                           industry  \
# 0                Mid-Level     Data & Analytics, Healthcare, Medical Software
# 1  Mid-Level, Senior, Lead                         eCommerce, Fashion, Retail
# 2        Mid-Level, Senior                                      Biotechnology
# 3                   Senior  Financial Technology, Government, Software Dev...
# 4                   Senior  Financial Technology, Government, Software Dev...
#
#     job-type                                               link  \
# 0  Full-time          /jobs/199604/data-scientist-etiometry-inc
# 1  Full-time  /jobs/199609/senior-platform-developer-backend...
# 2  Full-time  /jobs/204842/senior-platform-engineer-pear-the...
# 3  Full-time  /jobs/157266/senior-java-developer-integrated-...
# 4  Full-time  /jobs/141988/senior-oracle-plsql-developer-int...
#
#         location moeda_original            perks                     posted  \
# 0         Boston              -  Paid relocation 2019-01-07 19:51:19.033107
# 1  San Francisco              -              NaN 2019-01-07 21:51:19.064124
# 2  San Francisco              -              NaN 2019-01-07 21:51:19.095266
# 3    Los Angeles              -           Remote 2019-01-07 21:51:19.125580
# 4    Los Angeles              -           Remote 2019-01-07 21:51:19.160225
#
#                      role salary salary_max salary_min  \
# 0          Data Scientist      0          0          0
# 1       Backend Developer      0          0          0
# 2    Full Stack Developer      0          0          0
# 3    Full Stack Developer      0          0          0
# 4  Database Administrator      0          0          0
#
#                                              tags  \
# 0                   python, medical, data-science
# 1                           ruby-on-rails, elixir
# 2  node.js, mysql, rest, ecmascript-6, javascript
# 3        java-ee, spring, oracle, weblogic, jboss
# 4   plsql, oracle, sql, rdbms, database, sysadmin
#
#                                            title
# 0                                 Data Scientist
# 1  Senior Platform Developer (Backend Developer)
# 2                       Senior Platform Engineer
# 3                          Senior Java Developer
# 4                  Senior Oracle PLSQL Developer

# %%
def converter_para_real(row):
    moeda = 0
    if row['moeda_original'] != '-':
        moeda = moedas[row['moeda_original']]
        
    row['salary_min'] = math.floor((moeda * int(row['salary_min'])) / 12)
    row['salary_max'] = math.ceil((moeda * int(row['salary_max'])) / 12)
    row['salary_mean'] = row[['salary_min','salary_max']].mean()
    return row

df = df.apply(converter_para_real, axis=1)
df = df.drop(['salary'], axis=1)
df.head()
# Out:
#                                     company   company-size company-type  \
# 0                  Etiometry Inc.\n           11-50 people      Private
# 1                   The Real Real\n           1k-5k people      Private
# 2               Pear Therapeutics\n          51-200 people      Private
# 3  Integrated Data Services (IDS)\n          51-200 people      Private
# 4  Integrated Data Services (IDS)\n          51-200 people      Private
#
#               country                                        description  \
# 0  Massachusetts, EUA  \nWe are currently seeking a Data Scientist to...
# 1     Califórnia, EUA  \nThe RealReal is leading the way in authentic...
# 2     Califórnia, EUA  \nAbout Pear Therapeutics \nAt Pear, our missi...
# 3     Califórnia, EUA  \nSenior Java Developer\nLos Angeles, CA; Wash...
# 4     Califórnia, EUA  \nSenior Oracle PLSQL Developer\nLos Angeles, ...
#
#           experience-level                                           industry  \
# 0                Mid-Level     Data & Analytics, Healthcare, Medical Software
# 1  Mid-Level, Senior, Lead                         eCommerce, Fashion, Retail
# 2        Mid-Level, Senior                                      Biotechnology
# 3                   Senior  Financial Technology, Government, Software Dev...
# 4                   Senior  Financial Technology, Government, Software Dev...
#
#     job-type                                               link  \
# 0  Full-time          /jobs/199604/data-scientist-etiometry-inc
# 1  Full-time  /jobs/199609/senior-platform-developer-backend...
# 2  Full-time  /jobs/204842/senior-platform-engineer-pear-the...
# 3  Full-time  /jobs/157266/senior-java-developer-integrated-...
# 4  Full-time  /jobs/141988/senior-oracle-plsql-developer-int...
#
#         location moeda_original            perks                     posted  \
# 0         Boston              -  Paid relocation 2019-01-07 19:51:19.033107
# 1  San Francisco              -              NaN 2019-01-07 21:51:19.064124
# 2  San Francisco              -              NaN 2019-01-07 21:51:19.095266
# 3    Los Angeles              -           Remote 2019-01-07 21:51:19.125580
# 4    Los Angeles              -           Remote 2019-01-07 21:51:19.160225
#
#                      role  salary_max  salary_min  \
# 0          Data Scientist           0           0
# 1       Backend Developer           0           0
# 2    Full Stack Developer           0           0
# 3    Full Stack Developer           0           0
# 4  Database Administrator           0           0
#
#                                              tags  \
# 0                   python, medical, data-science
# 1                           ruby-on-rails, elixir
# 2  node.js, mysql, rest, ecmascript-6, javascript
# 3        java-ee, spring, oracle, weblogic, jboss
# 4   plsql, oracle, sql, rdbms, database, sysadmin
#
#                                            title  salary_mean
# 0                                 Data Scientist          0.0
# 1  Senior Platform Developer (Backend Developer)          0.0
# 2                       Senior Platform Engineer          0.0
# 3                          Senior Java Developer          0.0
# 4                  Senior Oracle PLSQL Developer          0.0

# %% [markdown]
# ### Company Size

# %%
size_dict = {
    '11-50 people': 50,
    '1k-5k people': 5000,
    '51-200 people': 200,
    '5k-10k people': 10000,
    '501-1k people': 1000,
    '1-10 people': 10,
    'nan': '-',
    '10k+ people': '+10000',
    '201-500 people': 500,
    '0+ people': 10,
    '0-0 people': '-'
}

df['company-size'] = df['company-size'].apply(lambda x: size_dict[str(x)])

# %%
df.head()
# Out:
#                                     company company-size company-type  \
# 0                  Etiometry Inc.\n                   50      Private
# 1                   The Real Real\n                 5000      Private
# 2               Pear Therapeutics\n                  200      Private
# 3  Integrated Data Services (IDS)\n                  200      Private
# 4  Integrated Data Services (IDS)\n                  200      Private
#
#               country                                        description  \
# 0  Massachusetts, EUA  \nWe are currently seeking a Data Scientist to...
# 1     Califórnia, EUA  \nThe RealReal is leading the way in authentic...
# 2     Califórnia, EUA  \nAbout Pear Therapeutics \nAt Pear, our missi...
# 3     Califórnia, EUA  \nSenior Java Developer\nLos Angeles, CA; Wash...
# 4     Califórnia, EUA  \nSenior Oracle PLSQL Developer\nLos Angeles, ...
#
#           experience-level                                           industry  \
# 0                Mid-Level     Data & Analytics, Healthcare, Medical Software
# 1  Mid-Level, Senior, Lead                         eCommerce, Fashion, Retail
# 2        Mid-Level, Senior                                      Biotechnology
# 3                   Senior  Financial Technology, Government, Software Dev...
# 4                   Senior  Financial Technology, Government, Software Dev...
#
#     job-type                                               link  \
# 0  Full-time          /jobs/199604/data-scientist-etiometry-inc
# 1  Full-time  /jobs/199609/senior-platform-developer-backend...
# 2  Full-time  /jobs/204842/senior-platform-engineer-pear-the...
# 3  Full-time  /jobs/157266/senior-java-developer-integrated-...
# 4  Full-time  /jobs/141988/senior-oracle-plsql-developer-int...
#
#         location moeda_original            perks                     posted  \
# 0         Boston              -  Paid relocation 2019-01-07 19:51:19.033107
# 1  San Francisco              -              NaN 2019-01-07 21:51:19.064124
# 2  San Francisco              -              NaN 2019-01-07 21:51:19.095266
# 3    Los Angeles              -           Remote 2019-01-07 21:51:19.125580
# 4    Los Angeles              -           Remote 2019-01-07 21:51:19.160225
#
#                      role  salary_max  salary_min  \
# 0          Data Scientist           0           0
# 1       Backend Developer           0           0
# 2    Full Stack Developer           0           0
# 3    Full Stack Developer           0           0
# 4  Database Administrator           0           0
#
#                                              tags  \
# 0                   python, medical, data-science
# 1                           ruby-on-rails, elixir
# 2  node.js, mysql, rest, ecmascript-6, javascript
# 3        java-ee, spring, oracle, weblogic, jboss
# 4   plsql, oracle, sql, rdbms, database, sysadmin
#
#                                            title  salary_mean
# 0                                 Data Scientist          0.0
# 1  Senior Platform Developer (Backend Developer)          0.0
# 2                       Senior Platform Engineer          0.0
# 3                          Senior Java Developer          0.0
# 4                  Senior Oracle PLSQL Developer          0.0

# %%
df = df[[
    'title','tags', 'perks', 'country',
    'location', 'company', 'company-size', 'company-type',
    'description','experience-level', 'industry', 'job-type',
    'link' , 'posted', 'moeda_original', 'role',
    'salary_min', 'salary_max', 'salary_mean']]

# %%
df.to_csv('data/Stack_Overflow_Jobs2.csv', index=False)

# %% [markdown]
# ### Criando Data Frame para as Tags

# %%
job_tags = []

def separate_tags(row):
    tags_dic = {'id': row.name}

    if not isinstance(row['tags'], float):
        tags = row['tags']
        
        for tag in tags.split(', '):
            tags_dic[tag] = 1
    
    job_tags.append(tags_dic)
    return row
    
    
_ = df.apply(separate_tags, axis=1)

# %%
del job_tags[0]

# %%
df_tags = pd.DataFrame(job_tags)

# %%
df_tags.shape
# Out:
# (1050, 575)

# %%
df_tags.head()
# Out:
#    .net  .net-core  .net-framework  2d  3d  ab-initio  actionscript  \
# 0   NaN        NaN             NaN NaN NaN        NaN           NaN
# 1   NaN        NaN             NaN NaN NaN        NaN           NaN
# 2   NaN        NaN             NaN NaN NaN        NaN           NaN
# 3   NaN        NaN             NaN NaN NaN        NaN           NaN
# 4   NaN        NaN             NaN NaN NaN        NaN           NaN
#
#    actionscript-2  admin  adobe-xd   ...     wordpress-rest-api  wpf  xamarin  \
# 0             NaN    NaN       NaN   ...                    NaN  NaN      NaN
# 1             NaN    NaN       NaN   ...                    NaN  NaN      NaN
# 2             NaN    NaN       NaN   ...                    NaN  NaN      NaN
# 3             NaN    NaN       NaN   ...                    NaN  NaN      NaN
# 4             NaN    NaN       NaN   ...                    NaN  NaN      NaN
#
#    xctest  xilinx  xml  xtend  yocto  zend-framework  zipline
# 0     NaN     NaN  NaN    NaN    NaN             NaN      NaN
# 1     NaN     NaN  NaN    NaN    NaN             NaN      NaN
# 2     NaN     NaN  NaN    NaN    NaN             NaN      NaN
# 3     NaN     NaN  NaN    NaN    NaN             NaN      NaN
# 4     NaN     NaN  NaN    NaN    NaN             NaN      NaN
#
# [5 rows x 575 columns]

# %%
df_tags.to_csv('data/jobs_tags.csv', index=False)

# %%
with open('data/tags_list.json', 'w') as file:
    json.dump(df_tags.columns.tolist(), file)
