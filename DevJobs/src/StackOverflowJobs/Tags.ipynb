# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.externals import joblib
import pandas as pd
from string import punctuation, digits
import re
#from DevJobs.settings import STACK_JOBS_DATA

vectorizer = None
tags_corr = None
df_tags = None
PATH_DATA = 'data/' #STACK_JOBS_DATA 

def _aplicar_tfidf(palavras = []):
    palavras = [_clean_tranform_str(p) for p in palavras]
    matrix_tfidf = vectorizer.transform(palavras)
    
    return pd.DataFrame(
        matrix_tfidf.todense(),
        columns=vectorizer.get_feature_names()
    )

def _tag_similar(df_tags, df_tfidf_tags, df_tfidf_analizar):
    df_tfidf = df_tfidf_tags.append(df_tfidf_analizar, ignore_index=True)
    sim_matriz = cosine_similarity(df_tfidf)
    
    sim_serie = pd.Series(sim_matriz[-1]).sort_values(ascending=False)

    if sim_serie.iloc[1] > 0.4:
        index_tag = df_tags.loc[sim_serie.index[1]].name
        return df_tags.columns[index_tag]
    else: return None


def _tags_correlacionadas(tag):
    return tags_corr[ tag ].sort_values(ascending=False)[:20]

def _clean_tranform_str(texto):
    processado = ' '.join([x for x in texto])
    processado += ' ' +  ' '.join([texto[i:i+2] for i, x in enumerate(texto[:-1])])
    return processado

def obter_tags_correlacionadas(descricao):
    tfidf_analizar = _aplicar_tfidf([descricao])
    tag_similar = _tag_similar(df_tags, tfidf_tags, tfidf_analizar)
    
    if not tag_similar: return []
    
    tags_correlacionadas = _tags_correlacionadas(tag_similar)
    return tags_correlacionadas.index.tolist()
    
    
def _inicializa():
    global tags_corr, tfidf_tags, df_tags, vectorizer

    df_tags = pd.read_csv(PATH_DATA + 'jobs_tags.csv')
    df_tags = df_tags.drop(['id'],axis=1)
    
    vectorizer = TfidfVectorizer(use_idf = False, token_pattern='\S+')
    vectorizer.fit_transform([ _clean_tranform_str(p) for p in df_tags.columns])
    '''vectorizer = joblib.load(PATH_DATA + 'vectorizer_tags.dat')'''
    
    tags_corr = df_tags.fillna(0).corr()
    tfidf_tags = _aplicar_tfidf(df_tags.columns)
    
_inicializa()

# %%
#joblib.dump(vectorizer, PATH_DATA + 'vectorizer_tags.dat')
# Out:
# ['data/vectorizer_tags.dat']

# %%
tfidf_analizar = _aplicar_tfidf(['tensor'])

# %%
_tag_similar(df_tags, tfidf_tags, tfidf_analizar )
# Out:
# 'tensorflow'

# %%
_clean_tranform_str('python')
# Out:
# 'p y t h o n py yt th ho on'

# %%
tfidf_tags[tfidf_tags.columns[65:75]]
# Out:
#             a   a-   aa        ab        ac        ad        af        ag  \
# 0    0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.179605  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 5    0.208514  0.0  0.0  0.208514  0.000000  0.000000  0.000000  0.000000
# 6    0.185695  0.0  0.0  0.000000  0.185695  0.000000  0.000000  0.000000
# 7    0.174078  0.0  0.0  0.000000  0.174078  0.000000  0.000000  0.000000
# 8    0.333333  0.0  0.0  0.000000  0.000000  0.333333  0.000000  0.000000
# 9    0.242536  0.0  0.0  0.000000  0.000000  0.242536  0.000000  0.000000
# 10   0.260378  0.0  0.0  0.000000  0.000000  0.130189  0.000000  0.000000
# 11   0.160128  0.0  0.0  0.000000  0.000000  0.000000  0.160128  0.000000
# 12   0.333333  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.333333
# 13   0.341882  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.227921
# 14   0.277350  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 15   0.666667  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 16   0.603023  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 17   0.485071  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 18   0.242536  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 19   0.436436  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 20   0.417029  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 21   0.328798  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 22   0.359211  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 23   0.458831  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 24   0.285714  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 25   0.447214  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 26   0.447214  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 27   0.377964  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 28   0.458831  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 29   0.258199  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# ..        ...  ...  ...       ...       ...       ...       ...       ...
# 544  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 545  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 546  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 547  0.301511  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 548  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 549  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 550  0.328798  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 551  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 552  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 553  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 554  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 555  0.277350  0.0  0.0  0.000000  0.277350  0.000000  0.000000  0.000000
# 556  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 557  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 558  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 559  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 560  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 561  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 562  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 563  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 564  0.132453  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 565  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 566  0.516398  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 567  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 568  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 569  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 570  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 571  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 572  0.179605  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 573  0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           ai        aj
# 0    0.00000  0.000000
# 1    0.00000  0.000000
# 2    0.00000  0.000000
# 3    0.00000  0.000000
# 4    0.00000  0.000000
# 5    0.00000  0.000000
# 6    0.00000  0.000000
# 7    0.00000  0.000000
# 8    0.00000  0.000000
# 9    0.00000  0.000000
# 10   0.00000  0.000000
# 11   0.00000  0.000000
# 12   0.00000  0.000000
# 13   0.00000  0.000000
# 14   0.27735  0.000000
# 15   0.00000  0.333333
# 16   0.00000  0.000000
# 17   0.00000  0.000000
# 18   0.00000  0.000000
# 19   0.00000  0.000000
# 20   0.00000  0.000000
# 21   0.00000  0.000000
# 22   0.00000  0.000000
# 23   0.00000  0.000000
# 24   0.00000  0.000000
# 25   0.00000  0.000000
# 26   0.00000  0.000000
# 27   0.00000  0.000000
# 28   0.00000  0.000000
# 29   0.00000  0.000000
# ..       ...       ...
# 544  0.00000  0.000000
# 545  0.00000  0.000000
# 546  0.00000  0.000000
# 547  0.00000  0.000000
# 548  0.00000  0.000000
# 549  0.00000  0.000000
# 550  0.00000  0.000000
# 551  0.00000  0.000000
# 552  0.00000  0.000000
# 553  0.00000  0.000000
# 554  0.00000  0.000000
# 555  0.00000  0.000000
# 556  0.00000  0.000000
# 557  0.00000  0.000000
# 558  0.00000  0.000000
# 559  0.00000  0.000000
# 560  0.00000  0.000000
# 561  0.00000  0.000000
# 562  0.00000  0.000000
# 563  0.00000  0.000000
# 564  0.00000  0.000000
# 565  0.00000  0.000000
# 566  0.00000  0.000000
# 567  0.00000  0.000000
# 568  0.00000  0.000000
# 569  0.00000  0.000000
# 570  0.00000  0.000000
# 571  0.00000  0.000000
# 572  0.00000  0.000000
# 573  0.00000  0.000000
#
# [574 rows x 10 columns]

# %%
obter_tags_correlacionadas('tenso')
# Out:
# ['tensorflow',
#  'pyspark',
#  'artificial-intelligence',
#  'computer-vision',
#  'nlp',
#  'machine-learning',
#  'python',
#  'hadoop',
#  'c++',
#  'amazon-web-services',
#  'sdk',
#  'yocto',
#  'mfc',
#  'jms',
#  'ibm-mq',
#  'websphere',
#  'jdbc',
#  'percona-xtradb-cluster',
#  'database-administration',
#  'robotframework']

# %%
df_tags.columns.tolist()
# Out:
# ['.net',
#  '.net-core',
#  '.net-framework',
#  '2d',
#  '3d',
#  'ab-initio',
#  'actionscript',
#  'actionscript-2',
#  'admin',
#  'adobe-xd',
#  'advanced-custom-fields',
#  'after-effects',
#  'agile',
#  'agile-project-management',
#  'airflow',
#  'ajax',
#  'akka',
#  'algolia',
#  'algorithm',
#  'amazon-ec2',
#  'amazon-emr',
#  'amazon-quicksight',
#  'amazon-redshift',
#  'amazon-s3',
#  'amazon-web-services',
#  'amd',
#  'ami',
#  'amqp',
#  'analysis',
#  'android',
#  'android-ndk',
#  'android-sdk-2.3',
#  'android-studio',
#  'angular',
#  'angular5',
#  'angular6',
#  'angularjs',
#  'animation',
#  'ansible',
#  'ant',
#  'apache',
#  'apache-kafka',
#  'apache-spark',
#  'apache-spark-sql',
#  'apex',
#  'api',
#  'api-design',
#  'apigee',
#  'appian',
#  'appkit',
#  'architecture',
#  'arkit',
#  'arm',
#  'artifactory',
#  'artificial-intelligence',
#  'asic',
#  'asp.net',
#  'asp.net-core',
#  'asp.net-mvc',
#  'asp.net-web-api',
#  'augmented-reality',
#  'automated-tests',
#  'automation',
#  'automotive',
#  'avfoundation',
#  'avplayer',
#  'aws',
#  'aws-aurora',
#  'aws-cognito',
#  'aws-lambda',
#  'axure',
#  'azure',
#  'azure-cosmosdb',
#  'azure-devops',
#  'azure-powershell',
#  'azure-service-fabric',
#  'babel',
#  'backbone.js',
#  'backend',
#  'bash',
#  'bigdata',
#  'blockchain',
#  'boost',
#  'boot',
#  'burp',
#  'business-intelligence',
#  'c',
#  'c#',
#  'c#-4.0',
#  'c++',
#  'c++11',
#  'c++14',
#  'calcite',
#  'can',
#  'can-bus',
#  'canopen',
#  'canvas',
#  'cassandra',
#  'cdn',
#  'centos',
#  'chef',
#  'client',
#  'clojure',
#  'clojurescript',
#  'cloud',
#  'cloudfoundry',
#  'cms',
#  'cocoa',
#  'cocoapods',
#  'code-review',
#  'computer-vision',
#  'confluence',
#  'confluence-rest-api',
#  'connectivity',
#  'connector',
#  'consensus',
#  'consumption',
#  'containers',
#  'content-management-system',
#  'contentful',
#  'continuous-delivery',
#  'continuous-deployment',
#  'continuous-integration',
#  'core',
#  'core-animation',
#  'core-data',
#  'coreml',
#  'cpu',
#  'cqrs',
#  'crm',
#  'cryengine',
#  'cryptography',
#  'css',
#  'css3',
#  'cucumber',
#  'cuda',
#  'cython',
#  'd3.js',
#  'dagger-2',
#  'dart',
#  'data-analysis',
#  'data-modeling',
#  'data-processing',
#  'data-science',
#  'data-structures',
#  'data-warehouse',
#  'database',
#  'database-administration',
#  'dax',
#  'db2',
#  'debian',
#  'deep-learning',
#  'delphi',
#  'dependency-injection',
#  'deployment',
#  'design',
#  'design-patterns',
#  'devops',
#  'devops-services',
#  'dhcp',
#  'directx',
#  'directx-11',
#  'distributed-system',
#  'distribution',
#  'dita',
#  'django',
#  'docker',
#  'doctrine2',
#  'domain-driven-design',
#  'dropwizard',
#  'drupal-8',
#  'e-commerce',
#  'eclipse',
#  'ecmascript-6',
#  'ejb',
#  'elasticsearch',
#  'elixir',
#  'embedded',
#  'embedded-linux',
#  'ember.js',
#  'enterprise',
#  'enterprise-architect',
#  'entity-framework',
#  'episerver',
#  'es6-modules',
#  'ethereum',
#  'etl',
#  'event-sourcing',
#  'excel-vba',
#  'exoplayer',
#  'express',
#  'extbase',
#  'extjs',
#  'extremeprogramming',
#  'finance',
#  'firebase',
#  'firebird',
#  'flash',
#  'flask',
#  'flow',
#  'fluid',
#  'fpga',
#  'front-end',
#  'frontend',
#  'functional-programming',
#  'game-development',
#  'gatsby',
#  'gcp',
#  'geospatial',
#  'gis',
#  'git',
#  'github',
#  'gitlab',
#  'go',
#  'google-chrome-extension',
#  'google-cloud-dlp',
#  'google-cloud-functions',
#  'google-cloud-platform',
#  'gpu',
#  'grafana',
#  'graph-databases',
#  'graphic-design',
#  'graphql',
#  'groovy',
#  'gsuite',
#  'guava',
#  'gwt',
#  'hadoop',
#  'hardware',
#  'hashicorp',
#  'haskell',
#  'havok',
#  'hbase',
#  'heroku',
#  'hibernate',
#  'hit',
#  'hive',
#  'hpc',
#  'hsm',
#  'html',
#  'html5',
#  'http',
#  'hybris',
#  'hyper-v',
#  'ibm-mq',
#  'ibm-sterling',
#  'iis',
#  'implementation',
#  'informatica',
#  'infrastructure',
#  'integration-testing',
#  'intel',
#  'interface-design',
#  'intrusion-detection',
#  'io',
#  'ios',
#  'iot',
#  'ipad',
#  'iphone',
#  'iso',
#  'itil',
#  'j1939',
#  'jasper',
#  'java',
#  'java-11',
#  'java-8',
#  'java-ee',
#  'javafx',
#  'javascript',
#  'jax-rs',
#  'jboss',
#  'jdbc',
#  'jenkins',
#  'jest',
#  'jetty',
#  'jira',
#  'jira-zephyr',
#  'jms',
#  'jpa',
#  'jquery',
#  'json',
#  'json.net',
#  'jsp',
#  'junit',
#  'jvm',
#  'kafka',
#  'kanban',
#  'kernel',
#  'kibana',
#  'koa',
#  'kotlin',
#  'kubernetes',
#  'kvm',
#  'lambda',
#  'language-agnostic',
#  'laravel',
#  'lead',
#  'linux',
#  'linux-kernel',
#  'lisp',
#  'lucene',
#  'machine-learning',
#  'macos',
#  'magento',
#  'manual-testing',
#  'mapreduce',
#  'mariadb',
#  'master-data-management',
#  'mathcad',
#  'matlab',
#  'maven',
#  'mdm',
#  'mdx',
#  'mediawiki',
#  'medical',
#  'mesos',
#  'metal',
#  'metaprogramming',
#  'metasploit',
#  'mfc',
#  'microcontroller',
#  'microprocessors',
#  'microservices',
#  'microstrategy',
#  'mirror',
#  'mobile',
#  'mobx',
#  'model-view-controller',
#  'modeling',
#  'module',
#  'mongodb',
#  'mssqlserver',
#  'multithreading',
#  'mvc',
#  'mvvm',
#  'mysql',
#  'neo4j',
#  'networking',
#  'nginx',
#  'nhibernate',
#  'nlp',
#  'node',
#  'node.js',
#  'nodejs',
#  'nosql',
#  'nservicebus',
#  'numpy',
#  'nunit',
#  'oauth-2.0',
#  'objective-c',
#  'offline',
#  'olap',
#  'oop',
#  'opengl',
#  'openid',
#  'openstack',
#  'operations',
#  'optimization',
#  'oracle',
#  'orm',
#  'osgi',
#  'osx',
#  'owasp',
#  'pandas',
#  'pci-compliance',
#  'pci-dss',
#  'pcie',
#  'percona-xtradb-cluster',
#  'perforce',
#  'performance-testing',
#  'perl',
#  'phoenix-framework',
#  'php',
#  'php-7',
#  'physx',
#  'pig',
#  'pki',
#  'platform',
#  'plsql',
#  'postcss',
#  'postgres',
#  'postgresql',
#  'powerbi',
#  'powershell',
#  'powershell-v4.0',
#  'pp',
#  'prettier',
#  'prism',
#  'product',
#  'production',
#  'project-management',
#  'projects-and-solutions',
#  'puppet',
#  'pyqtgraph',
#  'pyspark',
#  'python',
#  'python-3.x',
#  'qa',
#  'qgraphicsview',
#  'qlikview',
#  'qt',
#  'r',
#  'rabbitmq',
#  'rails',
#  'rdbms',
#  'react',
#  'react-apollo',
#  'react-fullstack',
#  'react-js',
#  'react-native',
#  'react-redux',
#  'reactive-programming',
#  'reactjs',
#  'reactor',
#  'real-time',
#  'redhat',
#  'redis',
#  'redux',
#  'redux-observable',
#  'reinforcement-learning',
#  'relational-database',
#  'reporting-services',
#  'requirements',
#  'responsive',
#  'responsive-design',
#  'rest',
#  'restful',
#  'restful-architecture',
#  'rethinkdb',
#  'rfid',
#  'robotframework',
#  'robotics',
#  'ros',
#  'ruby',
#  'ruby-on-rails',
#  'rust',
#  'rx-java',
#  'rx-swift',
#  'rx.js',
#  'rxjs',
#  'saas',
#  'sales',
#  'salesforce',
#  'salesforce-lightning',
#  'salt-stack',
#  'samba',
#  'san',
#  'sap',
#  'sapui5',
#  'sas',
#  'sass',
#  'scada',
#  'scala',
#  'scikit-learn',
#  'scripting',
#  'scrum',
#  'scss-mixins',
#  'sdk',
#  'sdlc',
#  'search',
#  'security',
#  'selenium',
#  'seo',
#  'serverless',
#  'servicenow',
#  'sgx',
#  'shell-scripting',
#  'simulink',
#  'sinatra',
#  'soa',
#  'soap',
#  'soapui',
#  'software-design',
#  'solr',
#  'spark',
#  'specifications',
#  'spinnaker',
#  'splunk',
#  'spring',
#  'spring-batch',
#  'spring-boot',
#  'spring-data',
#  'spring-kafka',
#  'spring-mvc',
#  'spring-web',
#  'sql',
#  'sql-server',
#  'sqlite',
#  'ssas',
#  'ssis',
#  'stackoverflow',
#  'startup',
#  'statistics',
#  'stl',
#  'stm32',
#  'stored-procedures',
#  'styled-components',
#  'supervised-learning',
#  'svn',
#  'swift',
#  'switching',
#  'sybase',
#  'symfony',
#  'symfony2',
#  'symfony3',
#  'sysadmin',
#  'sysml',
#  'system-administration',
#  'tableau',
#  'tcp',
#  'tcpdump',
#  'tdd',
#  'tensorflow',
#  'terraform',
#  'testing',
#  'tomcat',
#  'transcoding',
#  'trust-zone',
#  'trusted-computing',
#  'tsql',
#  'twitter-bootstrap',
#  'typescript',
#  'typo3',
#  'uat',
#  'udp',
#  'ui',
#  'ui-design',
#  'uikit',
#  'uml',
#  'unit-testing',
#  'unity3d',
#  'unix',
#  'unsupervised-learning',
#  'user-experience',
#  'user-interface',
#  'uwp',
#  'ux',
#  'vb.net',
#  'vba',
#  'verilog',
#  'virtualization',
#  'visual-studio',
#  'visualforce',
#  'vmware',
#  'vpn',
#  'vue.js',
#  'vuejs',
#  'vulkan',
#  'wcf',
#  'web',
#  'web-applications',
#  'web-services',
#  'webdriver',
#  'webix',
#  'weblogic',
#  'webpack',
#  'websecurity',
#  'websocket',
#  'websphere',
#  'wildfly-10',
#  'windows',
#  'windowsserver',
#  'winforms',
#  'wordpress',
#  'wordpress-rest-api',
#  'wpf',
#  'xamarin',
#  'xctest',
#  'xilinx',
#  'xml',
#  'xtend',
#  'yocto',
#  'zend-framework',
#  'zipline']
